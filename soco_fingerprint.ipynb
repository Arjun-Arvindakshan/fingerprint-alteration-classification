# %%
from imutils import paths
import os

# %%
from PIL import Image

# %%
import numpy as np
np.random.seed(42)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow import keras

# %%
tf.set_random_seed(42)

# %%
imgfiles = paths.list_images("samplefile/")
print(imgfiles)
# Out:
# <generator object list_files at 0x7fd2e9772ca8>

# %%
import glob

# %%
imgfiles1 = glob.glob("samplefile/*.PGM")
print(imgfiles1)
# Out:
# ['samplefile/64__M_Right_middle_finger_REAL_.PGM', 'samplefile/91__F_Right_index_finger_Obl.PGM', 'samplefile/88__F_Right_little_finger_Obl.PGM', 'samplefile/3__M_Left_little_finger_REAL_.PGM', 'samplefile/54__M_Right_thumb_finger_REAL_.PGM', 'samplefile/54__M_Right_index_finger_REAL_.PGM', 'samplefile/66__F_Right_ring_finger_Zcut.PGM', 'samplefile/80__M_Right_ring_finger_Obl.PGM', 'samplefile/31__F_Left_middle_finger_CR.PGM', 'samplefile/57__M_Right_thumb_finger_CR.PGM', 'samplefile/49__M_Left_thumb_finger_CR.PGM', 'samplefile/80__M_Left_little_finger_Obl.PGM', 'samplefile/75__F_Right_middle_finger_REAL_.PGM', 'samplefile/25__F_Left_index_finger_Obl.PGM', 'samplefile/8__M_Right_thumb_finger_REAL_.PGM', 'samplefile/74__F_Right_little_finger_Zcut.PGM', 'samplefile/79__M_Left_little_finger_CR.PGM', 'samplefile/42__F_Right_little_finger_CR.PGM', 'samplefile/62__M_Right_index_finger_CR.PGM', 'samplefile/89__M_Right_index_finger_Zcut.PGM', 'samplefile/58__M_Left_thumb_finger_CR.PGM', 'samplefile/6__M_Left_middle_finger_REAL_.PGM', 'samplefile/22__M_Left_little_finger_REAL_.PGM', 'samplefile/91__F_Right_ring_finger_Obl.PGM', 'samplefile/45__M_Right_ring_finger_REAL_.PGM', 'samplefile/46__M_Left_index_finger_CR.PGM', 'samplefile/75__F_Right_ring_finger_CR.PGM', 'samplefile/17__M_Right_little_finger_Zcut.PGM', 'samplefile/32__M_Right_index_finger_REAL_.PGM', 'samplefile/92__F_Left_ring_finger_REAL_.PGM', 'samplefile/10__M_Left_ring_finger_Zcut.PGM', 'samplefile/90__M_Left_little_finger_Zcut.PGM', 'samplefile/21__M_Left_index_finger_CR.PGM', 'samplefile/8__M_Left_middle_finger_Zcut.PGM', 'samplefile/25__F_Right_middle_finger_Zcut.PGM', 'samplefile/66__F_Left_ring_finger_REAL_.PGM', 'samplefile/94__M_Left_thumb_finger_CR.PGM', 'samplefile/77__M_Left_index_finger_REAL_.PGM', 'samplefile/30__F_Left_middle_finger_CR.PGM', 'samplefile/4__M_Right_middle_finger_REAL_.PGM', 'samplefile/52__M_Right_middle_finger_Zcut.PGM', 'samplefile/17__M_Left_index_finger_REAL_.PGM', 'samplefile/25__F_Right_middle_finger_Obl.PGM', 'samplefile/20__M_Right_little_finger_Obl.PGM', 'samplefile/49__M_Right_thumb_finger_CR.PGM', 'samplefile/9__M_Right_ring_finger_Zcut.PGM', 'samplefile/79__M_Left_ring_finger_Obl.PGM', 'samplefile/86__M_Right_index_finger_REAL_.PGM', 'samplefile/71__M_Left_thumb_finger_Zcut.PGM', 'samplefile/99__M_Right_index_finger_Obl.PGM', 'samplefile/96__M_Right_index_finger_Zcut.PGM', 'samplefile/40__F_Right_middle_finger_REAL_.PGM', 'samplefile/10__M_Left_middle_finger_REAL_.PGM', 'samplefile/11__M_Left_ring_finger_REAL_.PGM', 'samplefile/66__F_Left_ring_finger_Obl.PGM', 'samplefile/37__M_Right_ring_finger_Obl.PGM', 'samplefile/95__M_Right_ring_finger_CR.PGM', 'samplefile/47__F_Left_middle_finger_CR.PGM', 'samplefile/60__M_Right_ring_finger_Obl.PGM', 'samplefile/54__M_Right_ring_finger_REAL_.PGM', 'samplefile/96__M_Right_middle_finger_CR.PGM', 'samplefile/55__M_Right_thumb_finger_CR.PGM', 'samplefile/4__M_Right_index_finger_Zcut.PGM', 'samplefile/56__F_Right_index_finger_REAL_.PGM', 'samplefile/82__M_Left_little_finger_Zcut.PGM', 'samplefile/26__M_Left_middle_finger_REAL_.PGM', 'samplefile/64__M_Right_middle_finger_Zcut.PGM', 'samplefile/9__M_Right_little_finger_Obl.PGM', 'samplefile/29__F_Right_thumb_finger_REAL_.PGM', 'samplefile/4__M_Right_thumb_finger_REAL_.PGM', 'samplefile/78__F_Left_middle_finger_Obl.PGM', 'samplefile/73__M_Left_little_finger_Zcut.PGM', 'samplefile/32__M_Left_ring_finger_CR.PGM', 'samplefile/86__M_Left_thumb_finger_REAL_.PGM', 'samplefile/31__F_Right_middle_finger_Obl.PGM', 'samplefile/40__F_Right_index_finger_Obl.PGM', 'samplefile/33__M_Right_little_finger_Zcut.PGM', 'samplefile/98__M_Left_ring_finger_Obl.PGM', 'samplefile/79__M_Right_ring_finger_Obl.PGM', 'samplefile/24__F_Left_little_finger_Zcut.PGM', 'samplefile/86__M_Left_ring_finger_Zcut.PGM', 'samplefile/38__M_Left_index_finger_Obl.PGM', 'samplefile/92__F_Left_middle_finger_Zcut.PGM', 'samplefile/41__M_Left_ring_finger_Zcut.PGM', 'samplefile/59__F_Right_little_f ...

# %%
X = []
y = []

# %%
for fname in imgfiles1:
    X_i = Image.open(fname)
    #print(fname)
    X_i = np.array(X_i.resize((64,64)))/ 255.0
    elist = fname.split(os.path.sep)
    print(elist)
    X.append(X_i)
    label = elist[1].split("_")
    print(label)
    #label = elist[1].split(".")
    label2 = label[6].split(".")
    print(label2)
    y.append(label2[0])
    #print(y)
# Out:
# ['samplefile', '64__M_Right_middle_finger_REAL_.PGM']
# ['64', '', 'M', 'Right', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '91__F_Right_index_finger_Obl.PGM']
# ['91', '', 'F', 'Right', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '88__F_Right_little_finger_Obl.PGM']
# ['88', '', 'F', 'Right', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '3__M_Left_little_finger_REAL_.PGM']
# ['3', '', 'M', 'Left', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '54__M_Right_thumb_finger_REAL_.PGM']
# ['54', '', 'M', 'Right', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '54__M_Right_index_finger_REAL_.PGM']
# ['54', '', 'M', 'Right', 'index', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '66__F_Right_ring_finger_Zcut.PGM']
# ['66', '', 'F', 'Right', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '80__M_Right_ring_finger_Obl.PGM']
# ['80', '', 'M', 'Right', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '31__F_Left_middle_finger_CR.PGM']
# ['31', '', 'F', 'Left', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '57__M_Right_thumb_finger_CR.PGM']
# ['57', '', 'M', 'Right', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '49__M_Left_thumb_finger_CR.PGM']
# ['49', '', 'M', 'Left', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '80__M_Left_little_finger_Obl.PGM']
# ['80', '', 'M', 'Left', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '75__F_Right_middle_finger_REAL_.PGM']
# ['75', '', 'F', 'Right', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '25__F_Left_index_finger_Obl.PGM']
# ['25', '', 'F', 'Left', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '8__M_Right_thumb_finger_REAL_.PGM']
# ['8', '', 'M', 'Right', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '74__F_Right_little_finger_Zcut.PGM']
# ['74', '', 'F', 'Right', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '79__M_Left_little_finger_CR.PGM']
# ['79', '', 'M', 'Left', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '42__F_Right_little_finger_CR.PGM']
# ['42', '', 'F', 'Right', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '62__M_Right_index_finger_CR.PGM']
# ['62', '', 'M', 'Right', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '89__M_Right_index_finger_Zcut.PGM']
# ['89', '', 'M', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '58__M_Left_thumb_finger_CR.PGM']
# ['58', '', 'M', 'Left', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '6__M_Left_middle_finger_REAL_.PGM']
# ['6', '', 'M', 'Left', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '22__M_Left_little_finger_REAL_.PGM']
# ['22', '', 'M', 'Left', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '91__F_Right_ring_finger_Obl.PGM']
# ['91', '', 'F', 'Right', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '45__M_Right_ring_finger_REAL_.PGM']
# ['45', '', 'M', 'Right', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '46__M_Left_index_finger_CR.PGM']
# ['46', '', 'M', 'Left', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '75__F_Right_ring_finger_CR.PGM']
# ['75', '', 'F', 'Right', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '17__M_Right_little_finger_Zcut.PGM']
# ['17', '', 'M', 'Right', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '32__M_Right_index_finger_REAL_.PGM']
# ['32', '', 'M', 'Right', 'index', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '92__F_Left_ring_finger_REAL_.PGM']
# ['92', '', 'F', 'Left', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '10__M_Left_ring_finger_Zcut.PGM']
# ['10', '', 'M', 'Left', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '90__M_Left_little_finger_Zcut.PGM']
# ['90', '', 'M', 'Left', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '21__M_Left_index_finger_CR.PGM']
# ['21', '', 'M', 'Left', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '8__M_Left_middle_finger_Zcut.PGM']
# ['8', '', 'M', 'Left', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '25__F_Right_middle_finger_Zcut.PGM']
# ['25', '', 'F', 'Right', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '66__F_Left_ring_finger_REAL_.PGM']
# ['66', '', 'F', 'Left', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '94__M_Left_thumb_finger_CR.PGM']
# ['94', '', 'M', 'Left', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '77__M_Left_index_finger_REAL_.PGM']
# ['77', '', 'M', 'Left', 'index', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '30__F_Left_middle_finger_CR.PGM']
# ['30', '', 'F', 'Left', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '4__M_Right_middle_finger_REAL_.PGM']
# ['4', '', 'M', 'Right', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '52__M_Right_middle_finger_Zcut.PGM']
# ['52', '', 'M', 'Right', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '17__M_Left_index_finger_REAL_.PGM']
# ['17', '', 'M', 'Left', 'index', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '25__F_Right_middle_finger_Obl.PGM']
# ['25', '', 'F', 'Right', 'middle', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '20__M_Right_little_finger_Obl.PGM']
# ['20', '', 'M', 'Right', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '49__M_Right_thumb_finger_CR.PGM']
# ['49', '', 'M', 'Right', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '9__M_Right_ring_finger_Zcut.PGM']
# ['9', '', 'M', 'Right', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '79__M_Left_ring_finger_Obl.PGM']
# ['79', '', 'M', 'Left', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '86__M_Right_index_finger_REAL_.PGM']
# ['86', '', 'M', 'Right', 'index', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '71__M_Left_thumb_finger_Zcut.PGM']
# ['71', '', 'M', 'Left', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '99__M_Right_index_finger_Obl.PGM']
# ['99', '', 'M', 'Right', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '96__M_Right_index_finger_Zcut.PGM']
# ['96', '', 'M', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '40__F_Right_middle_finger_REAL_.PGM']
# ['40', '', 'F', 'Right', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '10__M_Left_middle_finger_REAL_.PGM']
# ['10', '', 'M', 'Left', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '11__M_Left_ring_finger_REAL_.PGM']
# ['11', '', 'M', 'Left', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '66__F_Left_ring_finger_Obl.PGM']
# ['66', '', 'F', 'Left', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '37__M_Right_ring_finger_Obl.PGM']
# ['37', '', 'M', 'Right', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '95__M_Right_ring_finger_CR.PGM']
# ['95', '', 'M', 'Right', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '47__F_Left_middle_finger_CR.PGM']
# ['47', '', 'F', 'Left', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '60__M_Right_ring_finger_Obl.PGM']
# ['60', '', 'M', 'Right', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '54__M_Right_ring_finger_REAL_.PGM']
# ['54', '', 'M', 'Right', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '96__M_Right_middle_finger_CR.PGM']
# ['96', '', 'M', 'Right', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '55__M_Right_thumb_finger_CR.PGM']
# ['55', '', 'M', 'Right', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '4__M_Right_index_finger_Zcut.PGM']
# ['4', '', 'M', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '56__F_Right_index_finger_REAL_.PGM']
# ['56', '', 'F', 'Right', 'index', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '82__M_Left_little_finger_Zcut.PGM']
# ['82', '', 'M', 'Left', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '26__M_Left_middle_finger_REAL_.PGM']
# ['26', '', 'M', 'Left', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '64__M_Right_middle_finger_Zcut.PGM']
# ['64', '', 'M', 'Right', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '9__M_Right_little_finger_Obl.PGM']
# ['9', '', 'M', 'Right', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '29__F_Right_thumb_finger_REAL_.PGM']
# ['29', '', 'F', 'Right', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '4__M_Right_thumb_finger_REAL_.PGM']
# ['4', '', 'M', 'Right', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '78__F_Left_middle_finger_Obl.PGM']
# ['78', '', 'F', 'Left', 'middle', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '73__M_Left_little_finger_Zcut.PGM']
# ['73', '', 'M', 'Left', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '32__M_Left_ring_finger_CR.PGM']
# ['32', '', 'M', 'Left', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '86__M_Left_thumb_finger_REAL_.PGM']
# ['86', '', 'M', 'Left', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '31__F_Right_middle_finger_Obl.PGM']
# ['31', '', 'F', 'Right', 'middle', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '40__F_Right_index_finger_Obl.PGM']
# ['40', '', 'F', 'Right', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '33__M_Right_little_finger_Zcut.PGM']
# ['33', '', 'M', 'Right', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '98__M_Left_ring_finger_Obl.PGM']
# ['98', '', 'M', 'Left', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '79__M_Right_ring_finger_Obl.PGM']
# ['79', '', 'M', 'Right', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '24__F_Left_little_finger_Zcut.PGM']
# ['24', '', 'F', 'Left', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '86__M_Left_ring_finger_Zcut.PGM']
# ['86', '', 'M', 'Left', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '38__M_Left_index_finger_Obl.PGM']
# ['38', '', 'M', 'Left', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '92__F_Left_middle_finger_Zcut.PGM']
# ['92', '', 'F', 'Left', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '41__M_Left_ring_finger_Zcut.PGM']
# ['41', '', 'M', 'Left', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '59__F_Right_little_finger_Obl.PGM']
# ['59', '', 'F', 'Right', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '4__M_Left_little_finger_Obl.PGM']
# ['4', '', 'M', 'Left', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '89__M_Right_little_finger_REAL_.PGM']
# ['89', '', 'M', 'Right', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '45__M_Right_index_finger_Zcut.PGM']
# ['45', '', 'M', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '65__M_Left_thumb_finger_Zcut.PGM']
# ['65', '', 'M', 'Left', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '43__F_Right_thumb_finger_CR.PGM']
# ['43', '', 'F', 'Right', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '75__F_Left_thumb_finger_REAL_.PGM']
# ['75', '', 'F', 'Left', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '33__M_Right_thumb_finger_REAL_.PGM']
# ['33', '', 'M', 'Right', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '59__F_Left_ring_finger_CR.PGM']
# ['59', '', 'F', 'Left', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '76__F_Left_index_finger_REAL_.PGM']
# ['76', '', 'F', 'Left', 'index', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '20__M_Left_ring_finger_Obl.PGM']
# ['20', '', 'M', 'Left', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '12__M_Right_middle_finger_REAL_.PGM']
# ['12', '', 'M', 'Right', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '92__F_Left_middle_finger_REAL_.PGM']
# ['92', '', 'F', 'Left', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '78__F_Left_middle_finger_REAL_.PGM']
# ['78', '', 'F', 'Left', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '27__M_Left_middle_finger_CR.PGM']
# ['27', '', 'M', 'Left', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '59__F_Left_middle_finger_Zcut.PGM']
# ['59', '', 'F', 'Left', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '35__M_Right_index_finger_CR.PGM']
# ['35', '', 'M', 'Right', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '69__M_Right_index_finger_CR.PGM']
# ['69', '', 'M', 'Right', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '18__M_Left_middle_finger_Obl.PGM']
# ['18', '', 'M', 'Left', 'middle', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '43__F_Left_thumb_finger_Zcut.PGM']
# ['43', '', 'F', 'Left', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '74__F_Left_index_finger_Obl.PGM']
# ['74', '', 'F', 'Left', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '13__F_Right_ring_finger_REAL_.PGM']
# ['13', '', 'F', 'Right', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '54__M_Left_thumb_finger_Zcut.PGM']
# ['54', '', 'M', 'Left', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '69__M_Left_little_finger_REAL_.PGM']
# ['69', '', 'M', 'Left', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '67__F_Right_index_finger_Obl.PGM']
# ['67', '', 'F', 'Right', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '61__M_Left_ring_finger_CR.PGM']
# ['61', '', 'M', 'Left', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '96__M_Right_ring_finger_REAL_.PGM']
# ['96', '', 'M', 'Right', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '84__M_Left_ring_finger_Zcut.PGM']
# ['84', '', 'M', 'Left', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '55__M_Left_ring_finger_Obl.PGM']
# ['55', '', 'M', 'Left', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '31__F_Left_ring_finger_REAL_.PGM']
# ['31', '', 'F', 'Left', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '52__M_Left_ring_finger_REAL_.PGM']
# ['52', '', 'M', 'Left', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '11__M_Right_ring_finger_CR.PGM']
# ['11', '', 'M', 'Right', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '38__M_Left_middle_finger_Obl.PGM']
# ['38', '', 'M', 'Left', 'middle', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '95__M_Right_index_finger_Zcut.PGM']
# ['95', '', 'M', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '100__M_Right_ring_finger_Obl.PGM']
# ['100', '', 'M', 'Right', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '42__F_Left_thumb_finger_Obl.PGM']
# ['42', '', 'F', 'Left', 'thumb', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '28__M_Left_thumb_finger_Obl.PGM']
# ['28', '', 'M', 'Left', 'thumb', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '80__M_Right_ring_finger_CR.PGM']
# ['80', '', 'M', 'Right', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '100__M_Right_ring_finger_REAL_.PGM']
# ['100', '', 'M', 'Right', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '82__M_Left_thumb_finger_REAL_.PGM']
# ['82', '', 'M', 'Left', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '24__F_Right_middle_finger_CR.PGM']
# ['24', '', 'F', 'Right', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '6__M_Right_thumb_finger_REAL_.PGM']
# ['6', '', 'M', 'Right', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '65__M_Right_little_finger_REAL_.PGM']
# ['65', '', 'M', 'Right', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '58__M_Right_ring_finger_CR.PGM']
# ['58', '', 'M', 'Right', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '71__M_Right_thumb_finger_REAL_.PGM']
# ['71', '', 'M', 'Right', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '86__M_Right_ring_finger_CR.PGM']
# ['86', '', 'M', 'Right', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '88__F_Left_middle_finger_Zcut.PGM']
# ['88', '', 'F', 'Left', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '93__M_Right_ring_finger_CR.PGM']
# ['93', '', 'M', 'Right', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '94__M_Right_ring_finger_CR.PGM']
# ['94', '', 'M', 'Right', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '95__M_Left_ring_finger_CR.PGM']
# ['95', '', 'M', 'Left', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '60__M_Left_thumb_finger_REAL_.PGM']
# ['60', '', 'M', 'Left', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '78__F_Right_ring_finger_Zcut.PGM']
# ['78', '', 'F', 'Right', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '42__F_Right_index_finger_REAL_.PGM']
# ['42', '', 'F', 'Right', 'index', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '51__M_Right_index_finger_CR.PGM']
# ['51', '', 'M', 'Right', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '52__M_Right_middle_finger_REAL_.PGM']
# ['52', '', 'M', 'Right', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '10__M_Left_index_finger_Zcut.PGM']
# ['10', '', 'M', 'Left', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '33__M_Right_middle_finger_REAL_.PGM']
# ['33', '', 'M', 'Right', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '93__M_Left_little_finger_Zcut.PGM']
# ['93', '', 'M', 'Left', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '83__M_Right_middle_finger_Zcut.PGM']
# ['83', '', 'M', 'Right', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '100__M_Right_index_finger_REAL_.PGM']
# ['100', '', 'M', 'Right', 'index', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '93__M_Left_middle_finger_REAL_.PGM']
# ['93', '', 'M', 'Left', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '38__M_Left_ring_finger_CR.PGM']
# ['38', '', 'M', 'Left', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '6__M_Right_index_finger_Obl.PGM']
# ['6', '', 'M', 'Right', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '12__M_Right_ring_finger_CR.PGM']
# ['12', '', 'M', 'Right', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '68__M_Left_thumb_finger_CR.PGM']
# ['68', '', 'M', 'Left', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '4__M_Right_middle_finger_Zcut.PGM']
# ['4', '', 'M', 'Right', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '4__M_Left_middle_finger_Obl.PGM']
# ['4', '', 'M', 'Left', 'middle', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '78__F_Left_thumb_finger_Zcut.PGM']
# ['78', '', 'F', 'Left', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '6__M_Left_middle_finger_CR.PGM']
# ['6', '', 'M', 'Left', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '55__M_Right_thumb_finger_Obl.PGM']
# ['55', '', 'M', 'Right', 'thumb', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '64__M_Left_ring_finger_CR.PGM']
# ['64', '', 'M', 'Left', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '27__M_Left_ring_finger_Zcut.PGM']
# ['27', '', 'M', 'Left', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '73__M_Right_ring_finger_Obl.PGM']
# ['73', '', 'M', 'Right', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '100__M_Right_thumb_finger_Zcut.PGM']
# ['100', '', 'M', 'Right', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '18__M_Right_little_finger_REAL_.PGM']
# ['18', '', 'M', 'Right', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '55__M_Left_middle_finger_CR.PGM']
# ['55', '', 'M', 'Left', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '54__M_Right_ring_finger_Obl.PGM']
# ['54', '', 'M', 'Right', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '36__M_Right_thumb_finger_Obl.PGM']
# ['36', '', 'M', 'Right', 'thumb', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '79__M_Left_thumb_finger_Obl.PGM']
# ['79', '', 'M', 'Left', 'thumb', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '90__M_Right_ring_finger_Obl.PGM']
# ['90', '', 'M', 'Right', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '69__M_Left_middle_finger_CR.PGM']
# ['69', '', 'M', 'Left', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '87__M_Left_little_finger_CR.PGM']
# ['87', '', 'M', 'Left', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '28__M_Right_index_finger_CR.PGM']
# ['28', '', 'M', 'Right', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '73__M_Left_little_finger_Obl.PGM']
# ['73', '', 'M', 'Left', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '31__F_Left_index_finger_REAL_.PGM']
# ['31', '', 'F', 'Left', 'index', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '49__M_Right_little_finger_Zcut.PGM']
# ['49', '', 'M', 'Right', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '67__F_Right_index_finger_Zcut.PGM']
# ['67', '', 'F', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '77__M_Left_thumb_finger_REAL_.PGM']
# ['77', '', 'M', 'Left', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '27__M_Left_middle_finger_REAL_.PGM']
# ['27', '', 'M', 'Left', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '21__M_Left_little_finger_Obl.PGM']
# ['21', '', 'M', 'Left', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '80__M_Right_ring_finger_REAL_.PGM']
# ['80', '', 'M', 'Right', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '83__M_Left_middle_finger_REAL_.PGM']
# ['83', '', 'M', 'Left', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '93__M_Left_thumb_finger_CR.PGM']
# ['93', '', 'M', 'Left', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '100__M_Left_ring_finger_CR.PGM']
# ['100', '', 'M', 'Left', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '37__M_Right_thumb_finger_Obl.PGM']
# ['37', '', 'M', 'Right', 'thumb', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '54__M_Right_index_finger_Obl.PGM']
# ['54', '', 'M', 'Right', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '68__M_Left_thumb_finger_Obl.PGM']
# ['68', '', 'M', 'Left', 'thumb', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '68__M_Left_little_finger_Obl.PGM']
# ['68', '', 'M', 'Left', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '5__M_Right_index_finger_Zcut.PGM']
# ['5', '', 'M', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '41__M_Right_ring_finger_CR.PGM']
# ['41', '', 'M', 'Right', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '13__F_Left_thumb_finger_Zcut.PGM']
# ['13', '', 'F', 'Left', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '99__M_Left_ring_finger_REAL_.PGM']
# ['99', '', 'M', 'Left', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '52__M_Left_thumb_finger_Zcut.PGM']
# ['52', '', 'M', 'Left', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '100__M_Right_thumb_finger_Obl.PGM']
# ['100', '', 'M', 'Right', 'thumb', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '4__M_Left_middle_finger_CR.PGM']
# ['4', '', 'M', 'Left', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '100__M_Right_thumb_finger_CR.PGM']
# ['100', '', 'M', 'Right', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '93__M_Right_ring_finger_REAL_.PGM']
# ['93', '', 'M', 'Right', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '63__M_Right_little_finger_REAL_.PGM']
# ['63', '', 'M', 'Right', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '8__M_Left_ring_finger_REAL_.PGM']
# ['8', '', 'M', 'Left', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '2__F_Left_thumb_finger_REAL_.PGM']
# ['2', '', 'F', 'Left', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '10__M_Right_thumb_finger_CR.PGM']
# ['10', '', 'M', 'Right', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '65__M_Right_thumb_finger_Obl.PGM']
# ['65', '', 'M', 'Right', 'thumb', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '42__F_Left_ring_finger_Obl.PGM']
# ['42', '', 'F', 'Left', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '25__F_Right_little_finger_CR.PGM']
# ['25', '', 'F', 'Right', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '72__M_Left_ring_finger_Zcut.PGM']
# ['72', '', 'M', 'Left', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '13__F_Right_middle_finger_Zcut.PGM']
# ['13', '', 'F', 'Right', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '16__M_Right_index_finger_Zcut.PGM']
# ['16', '', 'M', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '86__M_Right_little_finger_Zcut.PGM']
# ['86', '', 'M', 'Right', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '24__F_Right_middle_finger_Obl.PGM']
# ['24', '', 'F', 'Right', 'middle', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '48__F_Left_index_finger_CR.PGM']
# ['48', '', 'F', 'Left', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '77__M_Right_little_finger_Zcut.PGM']
# ['77', '', 'M', 'Right', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '85__M_Right_ring_finger_Obl.PGM']
# ['85', '', 'M', 'Right', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '85__M_Left_little_finger_Zcut.PGM']
# ['85', '', 'M', 'Left', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '56__F_Left_thumb_finger_Zcut.PGM']
# ['56', '', 'F', 'Left', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '100__M_Right_index_finger_Obl.PGM']
# ['100', '', 'M', 'Right', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '2__F_Right_index_finger_Obl.PGM']
# ['2', '', 'F', 'Right', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '41__M_Right_thumb_finger_Zcut.PGM']
# ['41', '', 'M', 'Right', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '9__M_Left_index_finger_Zcut.PGM']
# ['9', '', 'M', 'Left', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '98__M_Left_index_finger_CR.PGM']
# ['98', '', 'M', 'Left', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '96__M_Left_ring_finger_REAL_.PGM']
# ['96', '', 'M', 'Left', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '86__M_Right_little_finger_REAL_.PGM']
# ['86', '', 'M', 'Right', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '34__M_Right_index_finger_Zcut.PGM']
# ['34', '', 'M', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '95__M_Left_index_finger_Zcut.PGM']
# ['95', '', 'M', 'Left', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '96__M_Left_little_finger_CR.PGM']
# ['96', '', 'M', 'Left', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '9__M_Left_ring_finger_Zcut.PGM']
# ['9', '', 'M', 'Left', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '50__M_Left_thumb_finger_REAL_.PGM']
# ['50', '', 'M', 'Left', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '70__M_Left_index_finger_Zcut.PGM']
# ['70', '', 'M', 'Left', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '90__M_Left_index_finger_Zcut.PGM']
# ['90', '', 'M', 'Left', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '13__F_Left_little_finger_Zcut.PGM']
# ['13', '', 'F', 'Left', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '80__M_Left_thumb_finger_CR.PGM']
# ['80', '', 'M', 'Left', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '17__M_Left_middle_finger_REAL_.PGM']
# ['17', '', 'M', 'Left', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '99__M_Right_thumb_finger_CR.PGM']
# ['99', '', 'M', 'Right', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '20__M_Left_thumb_finger_REAL_.PGM']
# ['20', '', 'M', 'Left', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '93__M_Right_ring_finger_Obl.PGM']
# ['93', '', 'M', 'Right', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '72__M_Left_little_finger_CR.PGM']
# ['72', '', 'M', 'Left', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '43__F_Right_little_finger_CR.PGM']
# ['43', '', 'F', 'Right', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '32__M_Right_little_finger_CR.PGM']
# ['32', '', 'M', 'Right', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '37__M_Right_middle_finger_Zcut.PGM']
# ['37', '', 'M', 'Right', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '55__M_Left_little_finger_REAL_.PGM']
# ['55', '', 'M', 'Left', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '98__M_Right_middle_finger_REAL_.PGM']
# ['98', '', 'M', 'Right', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '44__M_Right_index_finger_REAL_.PGM']
# ['44', '', 'M', 'Right', 'index', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '58__M_Left_index_finger_CR.PGM']
# ['58', '', 'M', 'Left', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '91__F_Right_middle_finger_Zcut.PGM']
# ['91', '', 'F', 'Right', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '38__M_Left_thumb_finger_CR.PGM']
# ['38', '', 'M', 'Left', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '81__F_Left_middle_finger_REAL_.PGM']
# ['81', '', 'F', 'Left', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '42__F_Right_ring_finger_CR.PGM']
# ['42', '', 'F', 'Right', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '6__M_Left_little_finger_CR.PGM']
# ['6', '', 'M', 'Left', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '40__F_Left_middle_finger_Obl.PGM']
# ['40', '', 'F', 'Left', 'middle', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '3__M_Right_ring_finger_Zcut.PGM']
# ['3', '', 'M', 'Right', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '67__F_Right_little_finger_Zcut.PGM']
# ['67', '', 'F', 'Right', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '36__M_Right_middle_finger_Zcut.PGM']
# ['36', '', 'M', 'Right', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '100__M_Left_thumb_finger_REAL_.PGM']
# ['100', '', 'M', 'Left', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '40__F_Left_thumb_finger_Obl.PGM']
# ['40', '', 'F', 'Left', 'thumb', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '79__M_Right_ring_finger_CR.PGM']
# ['79', '', 'M', 'Right', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '57__M_Left_thumb_finger_Obl.PGM']
# ['57', '', 'M', 'Left', 'thumb', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '59__F_Left_middle_finger_CR.PGM']
# ['59', '', 'F', 'Left', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '42__F_Left_ring_finger_Zcut.PGM']
# ['42', '', 'F', 'Left', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '33__M_Left_thumb_finger_CR.PGM']
# ['33', '', 'M', 'Left', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '64__M_Left_index_finger_CR.PGM']
# ['64', '', 'M', 'Left', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '74__F_Right_middle_finger_CR.PGM']
# ['74', '', 'F', 'Right', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '94__M_Left_index_finger_CR.PGM']
# ['94', '', 'M', 'Left', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '20__M_Left_middle_finger_Obl.PGM']
# ['20', '', 'M', 'Left', 'middle', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '98__M_Right_thumb_finger_REAL_.PGM']
# ['98', '', 'M', 'Right', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '19__M_Right_index_finger_Zcut.PGM']
# ['19', '', 'M', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '93__M_Right_index_finger_CR.PGM']
# ['93', '', 'M', 'Right', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '2__F_Left_index_finger_Obl.PGM']
# ['2', '', 'F', 'Left', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '14__M_Right_little_finger_REAL_.PGM']
# ['14', '', 'M', 'Right', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '70__M_Left_ring_finger_CR.PGM']
# ['70', '', 'M', 'Left', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '7__M_Right_thumb_finger_Obl.PGM']
# ['7', '', 'M', 'Right', 'thumb', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '71__M_Left_little_finger_CR.PGM']
# ['71', '', 'M', 'Left', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '17__M_Right_index_finger_REAL_.PGM']
# ['17', '', 'M', 'Right', 'index', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '84__M_Right_middle_finger_REAL_.PGM']
# ['84', '', 'M', 'Right', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '62__M_Right_little_finger_REAL_.PGM']
# ['62', '', 'M', 'Right', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '88__F_Left_middle_finger_CR.PGM']
# ['88', '', 'F', 'Left', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '32__M_Left_little_finger_Obl.PGM']
# ['32', '', 'M', 'Left', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '76__F_Left_middle_finger_REAL_.PGM']
# ['76', '', 'F', 'Left', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '5__M_Left_middle_finger_Zcut.PGM']
# ['5', '', 'M', 'Left', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '38__M_Right_thumb_finger_Obl.PGM']
# ['38', '', 'M', 'Right', 'thumb', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '80__M_Left_ring_finger_REAL_.PGM']
# ['80', '', 'M', 'Left', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '47__F_Right_thumb_finger_Zcut.PGM']
# ['47', '', 'F', 'Right', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '20__M_Left_little_finger_CR.PGM']
# ['20', '', 'M', 'Left', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '57__M_Right_middle_finger_Obl.PGM']
# ['57', '', 'M', 'Right', 'middle', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '74__F_Left_middle_finger_REAL_.PGM']
# ['74', '', 'F', 'Left', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '47__F_Right_ring_finger_REAL_.PGM']
# ['47', '', 'F', 'Right', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '88__F_Left_index_finger_REAL_.PGM']
# ['88', '', 'F', 'Left', 'index', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '44__M_Left_index_finger_CR.PGM']
# ['44', '', 'M', 'Left', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '43__F_Left_middle_finger_Zcut.PGM']
# ['43', '', 'F', 'Left', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '39__M_Right_ring_finger_Obl.PGM']
# ['39', '', 'M', 'Right', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '70__M_Right_index_finger_Obl.PGM']
# ['70', '', 'M', 'Right', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '70__M_Right_index_finger_Zcut.PGM']
# ['70', '', 'M', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '4__M_Left_little_finger_CR.PGM']
# ['4', '', 'M', 'Left', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '68__M_Right_thumb_finger_REAL_.PGM']
# ['68', '', 'M', 'Right', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '57__M_Left_index_finger_CR.PGM']
# ['57', '', 'M', 'Left', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '11__M_Right_middle_finger_Zcut.PGM']
# ['11', '', 'M', 'Right', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '88__F_Left_little_finger_REAL_.PGM']
# ['88', '', 'F', 'Left', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '29__F_Right_index_finger_Obl.PGM']
# ['29', '', 'F', 'Right', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '27__M_Left_index_finger_Obl.PGM']
# ['27', '', 'M', 'Left', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '85__M_Right_index_finger_CR.PGM']
# ['85', '', 'M', 'Right', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '42__F_Left_little_finger_Zcut.PGM']
# ['42', '', 'F', 'Left', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '3__M_Left_index_finger_REAL_.PGM']
# ['3', '', 'M', 'Left', 'index', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '11__M_Left_little_finger_Obl.PGM']
# ['11', '', 'M', 'Left', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '4__M_Left_index_finger_CR.PGM']
# ['4', '', 'M', 'Left', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '79__M_Right_ring_finger_REAL_.PGM']
# ['79', '', 'M', 'Right', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '33__M_Left_thumb_finger_REAL_.PGM']
# ['33', '', 'M', 'Left', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '55__M_Right_thumb_finger_REAL_.PGM']
# ['55', '', 'M', 'Right', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '2__F_Right_ring_finger_CR.PGM']
# ['2', '', 'F', 'Right', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '35__M_Left_thumb_finger_CR.PGM']
# ['35', '', 'M', 'Left', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '96__M_Right_little_finger_Obl.PGM']
# ['96', '', 'M', 'Right', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '56__F_Left_ring_finger_CR.PGM']
# ['56', '', 'F', 'Left', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '93__M_Left_thumb_finger_Zcut.PGM']
# ['93', '', 'M', 'Left', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '90__M_Left_thumb_finger_Obl.PGM']
# ['90', '', 'M', 'Left', 'thumb', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '62__M_Left_thumb_finger_REAL_.PGM']
# ['62', '', 'M', 'Left', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '21__M_Left_thumb_finger_Zcut.PGM']
# ['21', '', 'M', 'Left', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '34__M_Right_middle_finger_CR.PGM']
# ['34', '', 'M', 'Right', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '48__F_Right_thumb_finger_REAL_.PGM']
# ['48', '', 'F', 'Right', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '2__F_Right_ring_finger_Obl.PGM']
# ['2', '', 'F', 'Right', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '75__F_Right_middle_finger_Zcut.PGM']
# ['75', '', 'F', 'Right', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '53__M_Left_little_finger_CR.PGM']
# ['53', '', 'M', 'Left', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '12__M_Left_index_finger_Obl.PGM']
# ['12', '', 'M', 'Left', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '55__M_Right_index_finger_REAL_.PGM']
# ['55', '', 'M', 'Right', 'index', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '47__F_Left_thumb_finger_Zcut.PGM']
# ['47', '', 'F', 'Left', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '99__M_Right_thumb_finger_REAL_.PGM']
# ['99', '', 'M', 'Right', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '67__F_Left_ring_finger_Zcut.PGM']
# ['67', '', 'F', 'Left', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '77__M_Right_index_finger_Zcut.PGM']
# ['77', '', 'M', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '14__M_Left_middle_finger_Zcut.PGM']
# ['14', '', 'M', 'Left', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '96__M_Left_middle_finger_Zcut.PGM']
# ['96', '', 'M', 'Left', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '2__F_Right_little_finger_REAL_.PGM']
# ['2', '', 'F', 'Right', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '23__M_Right_index_finger_Zcut.PGM']
# ['23', '', 'M', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '60__M_Right_little_finger_Zcut.PGM']
# ['60', '', 'M', 'Right', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '9__M_Left_middle_finger_Obl.PGM']
# ['9', '', 'M', 'Left', 'middle', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '12__M_Right_middle_finger_CR.PGM']
# ['12', '', 'M', 'Right', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '64__M_Right_ring_finger_CR.PGM']
# ['64', '', 'M', 'Right', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '34__M_Left_middle_finger_REAL_.PGM']
# ['34', '', 'M', 'Left', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '52__M_Left_index_finger_Obl.PGM']
# ['52', '', 'M', 'Left', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '72__M_Right_thumb_finger_REAL_.PGM']
# ['72', '', 'M', 'Right', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '44__M_Left_little_finger_Obl.PGM']
# ['44', '', 'M', 'Left', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '27__M_Right_thumb_finger_Zcut.PGM']
# ['27', '', 'M', 'Right', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '54__M_Right_ring_finger_Zcut.PGM']
# ['54', '', 'M', 'Right', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '17__M_Left_ring_finger_Obl.PGM']
# ['17', '', 'M', 'Left', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '38__M_Left_little_finger_Zcut.PGM']
# ['38', '', 'M', 'Left', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '57__M_Left_little_finger_CR.PGM']
# ['57', '', 'M', 'Left', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '10__M_Right_middle_finger_CR.PGM']
# ['10', '', 'M', 'Right', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '69__M_Right_index_finger_Zcut.PGM']
# ['69', '', 'M', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '98__M_Right_middle_finger_CR.PGM']
# ['98', '', 'M', 'Right', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '78__F_Right_little_finger_Zcut.PGM']
# ['78', '', 'F', 'Right', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '76__F_Right_ring_finger_Obl.PGM']
# ['76', '', 'F', 'Right', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '18__M_Left_thumb_finger_CR.PGM']
# ['18', '', 'M', 'Left', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '74__F_Right_little_finger_Obl.PGM']
# ['74', '', 'F', 'Right', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '1__M_Right_thumb_finger_Obl.PGM']
# ['1', '', 'M', 'Right', 'thumb', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '40__F_Right_index_finger_CR.PGM']
# ['40', '', 'F', 'Right', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '77__M_Right_ring_finger_Obl.PGM']
# ['77', '', 'M', 'Right', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '46__M_Right_ring_finger_CR.PGM']
# ['46', '', 'M', 'Right', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '92__F_Left_thumb_finger_Zcut.PGM']
# ['92', '', 'F', 'Left', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '21__M_Left_middle_finger_Zcut.PGM']
# ['21', '', 'M', 'Left', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '53__M_Left_thumb_finger_CR.PGM']
# ['53', '', 'M', 'Left', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '83__M_Right_thumb_finger_CR.PGM']
# ['83', '', 'M', 'Right', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '39__M_Left_middle_finger_REAL_.PGM']
# ['39', '', 'M', 'Left', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '63__M_Right_index_finger_Obl.PGM']
# ['63', '', 'M', 'Right', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '17__M_Right_ring_finger_REAL_.PGM']
# ['17', '', 'M', 'Right', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '10__M_Right_ring_finger_Zcut.PGM']
# ['10', '', 'M', 'Right', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '12__M_Left_little_finger_Zcut.PGM']
# ['12', '', 'M', 'Left', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '57__M_Right_thumb_finger_REAL_.PGM']
# ['57', '', 'M', 'Right', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '37__M_Left_thumb_finger_CR.PGM']
# ['37', '', 'M', 'Left', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '85__M_Left_ring_finger_REAL_.PGM']
# ['85', '', 'M', 'Left', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '100__M_Right_thumb_finger_REAL_.PGM']
# ['100', '', 'M', 'Right', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '78__F_Left_ring_finger_Obl.PGM']
# ['78', '', 'F', 'Left', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '14__M_Left_thumb_finger_CR.PGM']
# ['14', '', 'M', 'Left', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '9__M_Left_thumb_finger_CR.PGM']
# ['9', '', 'M', 'Left', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '80__M_Left_index_finger_Obl.PGM']
# ['80', '', 'M', 'Left', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '70__M_Right_middle_finger_Zcut.PGM']
# ['70', '', 'M', 'Right', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '5__M_Right_ring_finger_Zcut.PGM']
# ['5', '', 'M', 'Right', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '35__M_Right_ring_finger_REAL_.PGM']
# ['35', '', 'M', 'Right', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '72__M_Left_thumb_finger_CR.PGM']
# ['72', '', 'M', 'Left', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '37__M_Left_index_finger_REAL_.PGM']
# ['37', '', 'M', 'Left', 'index', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '51__M_Right_thumb_finger_REAL_.PGM']
# ['51', '', 'M', 'Right', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '69__M_Right_ring_finger_CR.PGM']
# ['69', '', 'M', 'Right', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '18__M_Left_thumb_finger_REAL_.PGM']
# ['18', '', 'M', 'Left', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '22__M_Left_little_finger_Obl.PGM']
# ['22', '', 'M', 'Left', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '10__M_Right_little_finger_Obl.PGM']
# ['10', '', 'M', 'Right', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '5__M_Left_thumb_finger_REAL_.PGM']
# ['5', '', 'M', 'Left', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '50__M_Left_index_finger_REAL_.PGM']
# ['50', '', 'M', 'Left', 'index', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '85__M_Left_thumb_finger_REAL_.PGM']
# ['85', '', 'M', 'Left', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '71__M_Left_ring_finger_Zcut.PGM']
# ['71', '', 'M', 'Left', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '42__F_Right_little_finger_REAL_.PGM']
# ['42', '', 'F', 'Right', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '94__M_Right_middle_finger_Obl.PGM']
# ['94', '', 'M', 'Right', 'middle', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '38__M_Left_thumb_finger_REAL_.PGM']
# ['38', '', 'M', 'Left', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '48__F_Right_middle_finger_CR.PGM']
# ['48', '', 'F', 'Right', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '78__F_Left_index_finger_REAL_.PGM']
# ['78', '', 'F', 'Left', 'index', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '41__M_Left_ring_finger_Obl.PGM']
# ['41', '', 'M', 'Left', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '50__M_Left_index_finger_CR.PGM']
# ['50', '', 'M', 'Left', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '93__M_Right_ring_finger_Zcut.PGM']
# ['93', '', 'M', 'Right', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '53__M_Right_middle_finger_REAL_.PGM']
# ['53', '', 'M', 'Right', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '17__M_Left_ring_finger_REAL_.PGM']
# ['17', '', 'M', 'Left', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '8__M_Right_thumb_finger_Zcut.PGM']
# ['8', '', 'M', 'Right', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '44__M_Right_middle_finger_Obl.PGM']
# ['44', '', 'M', 'Right', 'middle', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '67__F_Right_thumb_finger_Zcut.PGM']
# ['67', '', 'F', 'Right', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '82__M_Right_little_finger_CR.PGM']
# ['82', '', 'M', 'Right', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '8__M_Left_middle_finger_Obl.PGM']
# ['8', '', 'M', 'Left', 'middle', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '22__M_Right_middle_finger_CR.PGM']
# ['22', '', 'M', 'Right', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '49__M_Left_little_finger_CR.PGM']
# ['49', '', 'M', 'Left', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '4__M_Right_thumb_finger_CR.PGM']
# ['4', '', 'M', 'Right', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '7__M_Left_ring_finger_CR.PGM']
# ['7', '', 'M', 'Left', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '82__M_Left_thumb_finger_CR.PGM']
# ['82', '', 'M', 'Left', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '36__M_Left_ring_finger_CR.PGM']
# ['36', '', 'M', 'Left', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '87__M_Right_thumb_finger_CR.PGM']
# ['87', '', 'M', 'Right', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ...
# ['samplefile', '100__M_Right_little_finger_REAL_.PGM']
# ['100', '', 'M', 'Right', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '86__M_Left_middle_finger_Zcut.PGM']
# ['86', '', 'M', 'Left', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '11__M_Left_ring_finger_Zcut.PGM']
# ['11', '', 'M', 'Left', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '24__F_Right_ring_finger_Zcut.PGM']
# ['24', '', 'F', 'Right', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '15__F_Right_ring_finger_REAL_.PGM']
# ['15', '', 'F', 'Right', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '25__F_Left_little_finger_CR.PGM']
# ['25', '', 'F', 'Left', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '52__M_Left_middle_finger_CR.PGM']
# ['52', '', 'M', 'Left', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '36__M_Left_middle_finger_CR.PGM']
# ['36', '', 'M', 'Left', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '94__M_Right_index_finger_REAL_.PGM']
# ['94', '', 'M', 'Right', 'index', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '34__M_Left_ring_finger_REAL_.PGM']
# ['34', '', 'M', 'Left', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '92__F_Left_ring_finger_Obl.PGM']
# ['92', '', 'F', 'Left', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '70__M_Left_index_finger_Obl.PGM']
# ['70', '', 'M', 'Left', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '16__M_Right_ring_finger_Obl.PGM']
# ['16', '', 'M', 'Right', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '14__M_Right_thumb_finger_Zcut.PGM']
# ['14', '', 'M', 'Right', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '74__F_Right_ring_finger_Obl.PGM']
# ['74', '', 'F', 'Right', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '54__M_Right_middle_finger_CR.PGM']
# ['54', '', 'M', 'Right', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '73__M_Left_middle_finger_Zcut.PGM']
# ['73', '', 'M', 'Left', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '86__M_Right_index_finger_CR.PGM']
# ['86', '', 'M', 'Right', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '23__M_Left_little_finger_REAL_.PGM']
# ['23', '', 'M', 'Left', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '40__F_Left_little_finger_Zcut.PGM']
# ['40', '', 'F', 'Left', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '94__M_Right_middle_finger_REAL_.PGM']
# ['94', '', 'M', 'Right', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '36__M_Right_ring_finger_Zcut.PGM']
# ['36', '', 'M', 'Right', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '61__M_Right_middle_finger_Zcut.PGM']
# ['61', '', 'M', 'Right', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '12__M_Right_little_finger_Zcut.PGM']
# ['12', '', 'M', 'Right', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '17__M_Left_middle_finger_Zcut.PGM']
# ['17', '', 'M', 'Left', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '50__M_Right_index_finger_Obl.PGM']
# ['50', '', 'M', 'Right', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '36__M_Right_little_finger_Zcut.PGM']
# ['36', '', 'M', 'Right', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '100__M_Left_thumb_finger_CR.PGM']
# ['100', '', 'M', 'Left', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '13__F_Right_middle_finger_REAL_.PGM']
# ['13', '', 'F', 'Right', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '9__M_Right_index_finger_Zcut.PGM']
# ['9', '', 'M', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '76__F_Right_thumb_finger_Zcut.PGM']
# ['76', '', 'F', 'Right', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '6__M_Right_index_finger_Zcut.PGM']
# ['6', '', 'M', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '56__F_Right_middle_finger_Zcut.PGM']
# ['56', '', 'F', 'Right', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '52__M_Left_little_finger_Obl.PGM']
# ['52', '', 'M', 'Left', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '88__F_Left_ring_finger_Zcut.PGM']
# ['88', '', 'F', 'Left', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '35__M_Right_index_finger_Zcut.PGM']
# ['35', '', 'M', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '20__M_Left_little_finger_Zcut.PGM']
# ['20', '', 'M', 'Left', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '17__M_Left_little_finger_Obl.PGM']
# ['17', '', 'M', 'Left', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '12__M_Right_little_finger_Obl.PGM']
# ['12', '', 'M', 'Right', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '72__M_Left_thumb_finger_Zcut.PGM']
# ['72', '', 'M', 'Left', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '7__M_Left_little_finger_CR.PGM']
# ['7', '', 'M', 'Left', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '83__M_Right_little_finger_REAL_.PGM']
# ['83', '', 'M', 'Right', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '77__M_Right_middle_finger_CR.PGM']
# ['77', '', 'M', 'Right', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '35__M_Right_thumb_finger_REAL_.PGM']
# ['35', '', 'M', 'Right', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '98__M_Right_little_finger_Obl.PGM']
# ['98', '', 'M', 'Right', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '73__M_Right_index_finger_REAL_.PGM']
# ['73', '', 'M', 'Right', 'index', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '70__M_Left_little_finger_CR.PGM']
# ['70', '', 'M', 'Left', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '33__M_Right_little_finger_REAL_.PGM']
# ['33', '', 'M', 'Right', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '44__M_Right_thumb_finger_Obl.PGM']
# ['44', '', 'M', 'Right', 'thumb', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '88__F_Right_index_finger_Obl.PGM']
# ['88', '', 'F', 'Right', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '83__M_Right_middle_finger_REAL_.PGM']
# ['83', '', 'M', 'Right', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '26__M_Left_index_finger_CR.PGM']
# ['26', '', 'M', 'Left', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '1__M_Right_index_finger_Zcut.PGM']
# ['1', '', 'M', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '46__M_Right_middle_finger_Obl.PGM']
# ['46', '', 'M', 'Right', 'middle', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '25__F_Right_ring_finger_CR.PGM']
# ['25', '', 'F', 'Right', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '22__M_Left_ring_finger_Zcut.PGM']
# ['22', '', 'M', 'Left', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '79__M_Right_little_finger_Obl.PGM']
# ['79', '', 'M', 'Right', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '53__M_Right_index_finger_Obl.PGM']
# ['53', '', 'M', 'Right', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '95__M_Left_thumb_finger_CR.PGM']
# ['95', '', 'M', 'Left', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '26__M_Right_index_finger_CR.PGM']
# ['26', '', 'M', 'Right', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '47__F_Right_index_finger_Zcut.PGM']
# ['47', '', 'F', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '3__M_Left_thumb_finger_CR.PGM']
# ['3', '', 'M', 'Left', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '45__M_Right_middle_finger_CR.PGM']
# ['45', '', 'M', 'Right', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '42__F_Left_index_finger_Zcut.PGM']
# ['42', '', 'F', 'Left', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '30__F_Left_thumb_finger_REAL_.PGM']
# ['30', '', 'F', 'Left', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '46__M_Right_little_finger_CR.PGM']
# ['46', '', 'M', 'Right', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '68__M_Right_little_finger_REAL_.PGM']
# ['68', '', 'M', 'Right', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '58__M_Right_thumb_finger_Zcut.PGM']
# ['58', '', 'M', 'Right', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '68__M_Right_thumb_finger_Zcut.PGM']
# ['68', '', 'M', 'Right', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '36__M_Left_little_finger_Obl.PGM']
# ['36', '', 'M', 'Left', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '25__F_Left_thumb_finger_Zcut.PGM']
# ['25', '', 'F', 'Left', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '10__M_Left_little_finger_CR.PGM']
# ['10', '', 'M', 'Left', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '43__F_Left_little_finger_Zcut.PGM']
# ['43', '', 'F', 'Left', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '91__F_Left_index_finger_REAL_.PGM']
# ['91', '', 'F', 'Left', 'index', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '97__M_Left_middle_finger_Zcut.PGM']
# ['97', '', 'M', 'Left', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '3__M_Right_index_finger_Zcut.PGM']
# ['3', '', 'M', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '13__F_Right_index_finger_CR.PGM']
# ['13', '', 'F', 'Right', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '37__M_Right_middle_finger_CR.PGM']
# ['37', '', 'M', 'Right', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '93__M_Right_index_finger_REAL_.PGM']
# ['93', '', 'M', 'Right', 'index', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '85__M_Left_ring_finger_Zcut.PGM']
# ['85', '', 'M', 'Left', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '46__M_Right_little_finger_Zcut.PGM']
# ['46', '', 'M', 'Right', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '47__F_Right_ring_finger_Obl.PGM']
# ['47', '', 'F', 'Right', 'ring', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '55__M_Left_thumb_finger_CR.PGM']
# ['55', '', 'M', 'Left', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '4__M_Right_little_finger_REAL_.PGM']
# ['4', '', 'M', 'Right', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '48__F_Left_middle_finger_Zcut.PGM']
# ['48', '', 'F', 'Left', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '43__F_Right_ring_finger_CR.PGM']
# ['43', '', 'F', 'Right', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '24__F_Left_ring_finger_CR.PGM']
# ['24', '', 'F', 'Left', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '15__F_Right_index_finger_Zcut.PGM']
# ['15', '', 'F', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '67__F_Right_little_finger_CR.PGM']
# ['67', '', 'F', 'Right', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '67__F_Left_ring_finger_REAL_.PGM']
# ['67', '', 'F', 'Left', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '16__M_Left_little_finger_REAL_.PGM']
# ['16', '', 'M', 'Left', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '78__F_Right_ring_finger_CR.PGM']
# ['78', '', 'F', 'Right', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '69__M_Right_middle_finger_CR.PGM']
# ['69', '', 'M', 'Right', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '22__M_Right_index_finger_Zcut.PGM']
# ['22', '', 'M', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '3__M_Right_little_finger_Obl.PGM']
# ['3', '', 'M', 'Right', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '44__M_Left_thumb_finger_Obl.PGM']
# ['44', '', 'M', 'Left', 'thumb', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '67__F_Left_thumb_finger_CR.PGM']
# ['67', '', 'F', 'Left', 'thumb', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '86__M_Right_index_finger_Zcut.PGM']
# ['86', '', 'M', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '37__M_Right_thumb_finger_REAL_.PGM']
# ['37', '', 'M', 'Right', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '52__M_Right_ring_finger_CR.PGM']
# ['52', '', 'M', 'Right', 'ring', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '30__F_Right_middle_finger_Zcut.PGM']
# ['30', '', 'F', 'Right', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '46__M_Right_index_finger_Obl.PGM']
# ['46', '', 'M', 'Right', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '58__M_Right_middle_finger_REAL_.PGM']
# ['58', '', 'M', 'Right', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '90__M_Left_thumb_finger_REAL_.PGM']
# ['90', '', 'M', 'Left', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '69__M_Right_ring_finger_REAL_.PGM']
# ['69', '', 'M', 'Right', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '34__M_Left_thumb_finger_REAL_.PGM']
# ['34', '', 'M', 'Left', 'thumb', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '66__F_Right_index_finger_Obl.PGM']
# ['66', '', 'F', 'Right', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '34__M_Right_ring_finger_Zcut.PGM']
# ['34', '', 'M', 'Right', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '76__F_Left_ring_finger_REAL_.PGM']
# ['76', '', 'F', 'Left', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '61__M_Left_little_finger_REAL_.PGM']
# ['61', '', 'M', 'Left', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '86__M_Left_index_finger_CR.PGM']
# ['86', '', 'M', 'Left', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '30__F_Left_index_finger_Obl.PGM']
# ['30', '', 'F', 'Left', 'index', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '38__M_Right_little_finger_REAL_.PGM']
# ['38', '', 'M', 'Right', 'little', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '58__M_Right_little_finger_CR.PGM']
# ['58', '', 'M', 'Right', 'little', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '31__F_Left_thumb_finger_Obl.PGM']
# ['31', '', 'F', 'Left', 'thumb', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '54__M_Right_index_finger_Zcut.PGM']
# ['54', '', 'M', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '97__M_Right_index_finger_Zcut.PGM']
# ['97', '', 'M', 'Right', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '14__M_Right_middle_finger_Obl.PGM']
# ['14', '', 'M', 'Right', 'middle', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '1__M_Left_thumb_finger_Zcut.PGM']
# ['1', '', 'M', 'Left', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '22__M_Right_ring_finger_REAL_.PGM']
# ['22', '', 'M', 'Right', 'ring', 'finger', 'REAL', '.PGM']
# ['REAL']
# ['samplefile', '92__F_Left_middle_finger_CR.PGM']
# ['92', '', 'F', 'Left', 'middle', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '2__F_Left_middle_finger_Zcut.PGM']
# ['2', '', 'F', 'Left', 'middle', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '63__M_Right_little_finger_Zcut.PGM']
# ['63', '', 'M', 'Right', 'little', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '76__F_Left_thumb_finger_Obl.PGM']
# ['76', '', 'F', 'Left', 'thumb', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '64__M_Right_thumb_finger_Zcut.PGM']
# ['64', '', 'M', 'Right', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '99__M_Right_little_finger_Obl.PGM']
# ['99', '', 'M', 'Right', 'little', 'finger', 'Obl.PGM']
# ['Obl', 'PGM']
# ['samplefile', '61__M_Left_ring_finger_Zcut.PGM']
# ['61', '', 'M', 'Left', 'ring', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '45__M_Left_thumb_finger_Zcut.PGM']
# ['45', '', 'M', 'Left', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '66__F_Right_index_finger_CR.PGM']
# ['66', '', 'F', 'Right', 'index', 'finger', 'CR.PGM']
# ['CR', 'PGM']
# ['samplefile', '75__F_Right_thumb_finger_Zcut.PGM']
# ['75', '', 'F', 'Right', 'thumb', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '56__F_Left_index_finger_Zcut.PGM']
# ['56', '', 'F', 'Left', 'index', 'finger', 'Zcut.PGM']
# ['Zcut', 'PGM']
# ['samplefile', '39__M_Right_middle_finger_REAL_.PGM']
# ['39', '', 'M', 'Right', 'middle', 'finger', 'REAL', '.PGM']
# ['REAL']

# %%
print(set(y))
# Out:
# {'Zcut', 'REAL', 'CR', 'Obl'}

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lencoder = LabelEncoder()
y = lencoder.fit_transform(y)

# %%
print(set(y))
# Out:
# {0, 1, 2, 3}

# %%
print(lencoder.classes_)
# Out:
# ['CR' 'Obl' 'REAL' 'Zcut']

# %%
print(lencoder.inverse_transform([0]))
# Out:
# ['CR']

# %%
X = np.array(X)
y = np.array(y)
print(len(X))
print(len(y))
# Out:
# 3976
# 3976

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,stratify = y,random_state = 42)

# %%
print("X_train_shape:{}".format(X_train.shape))
# Out:
# X_train_shape:(3180, 64, 64)

# %%
print("X_test_shape:{}".format(X_test.shape))
# Out:
# X_test_shape:(796, 64, 64)

# %%
X_train = X_train[...,np.newaxis]

# %%
X_test = X_test[...,np.newaxis]

# %%
model_CNN = keras.models.Sequential()

# %%
model_CNN.add(keras.layers.Conv2D(filters=32,kernel_size = 7,padding = 'same',activation = 'relu',input_shape = [64,64,1]))
model_CNN.add(keras.layers.MaxPooling2D(pool_size = 2))
model_CNN.add(keras.layers.Conv2D(filters=64,kernel_size = 5,padding = 'same',activation = 'relu'))
model_CNN.add(keras.layers.MaxPooling2D(pool_size = 2))
model_CNN.add(keras.layers.Conv2D(filters=64,kernel_size = 3,padding = 'same',activation = 'relu'))
model_CNN.add(keras.layers.MaxPooling2D(pool_size = 2))
# Out:
# WARNING:tensorflow:From /home/arjun/miniconda3/envs/num_exe/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model_CNN.add(keras.layers.Flatten())
model_CNN.add(keras.layers.Dense(64,activation = 'relu'))
model_CNN.add(keras.layers.Dense(32,activation = 'relu'))
model_CNN.add(keras.layers.Dense(4,activation = 'softmax'))
model_CNN.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 32)        1600
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                262208
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 354,212
# Trainable params: 354,212
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_CNN.compile(loss="sparse_categorical_crossentropy",optimizer = 'adam',metrics = ["accuracy"])

# %%
history_CNN = model_CNN.fit(X_train,y_train,epochs = 20,validation_split=0.2)
# Out:
# Train on 2544 samples, validate on 636 samples
# Epoch 1/20
# 2544/2544 [==============================] - 141s 55ms/sample - loss: 1.3891 - acc: 0.2394 - val_loss: 1.3866 - val_acc: 0.2327
# Epoch 2/20
#  320/2544 [==>...........................] - ETA: 1:48 - loss: 1.3852 - acc: 0.3063

# %%
import pandas as pd

# %%
pd.DataFrame(history_CNN.history).plot()
plt.grid(True)
plt.xlabel("epochs")
plt.ylabel("loss/accuracy")
plt.title("training and validation plot")
plt.show()

# %%
test_loss,test_accuracy = model_CNN.evaluate(X_test,y_test)

# %%
print("test_loss {}","test_accuracy {}",(test_loss,test_accuracy))
